# %%
# !wget https://github.com/Dinesh-Adhithya-H/Digital-Image-Processing/raw/main/noisy-grayscale.png
# Out:
# --2022-01-27 04:07:52--  https://github.com/Dinesh-Adhithya-H/Digital-Image-Processing/raw/main/noisy-grayscale.png
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Dinesh-Adhithya-H/Digital-Image-Processing/main/noisy-grayscale.png [following]
# --2022-01-27 04:07:52--  https://raw.githubusercontent.com/Dinesh-Adhithya-H/Digital-Image-Processing/main/noisy-grayscale.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 345901 (338K) [image/png]
# Saving to: ‘noisy-grayscale.png’
#
# noisy-grayscale.png 100%[===================>] 337.79K  --.-KB/s    in 0.03s
#
# ...

# %%
import cv2
import imageio
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img=imageio.imread("noisy-grayscale.png")

# %%
plt.imshow(img)

# %%
blur_image = cv2.Me(img,(5,5),cv2.BORDER_DEFAULT)

# %%
# median_filtered= cv2.medianBlur(img,5)

# %%
plt.imshow(blur_image)

# %%
image = cv2.cvtColor(blur_image, cv2.COLOR_BGR2GRAY)


grad_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
grad_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)

abs_grad_x = cv2.convertScaleAbs(grad_x)
abs_grad_y = cv2.convertScaleAbs(grad_y)

grad = cv2.addWeighted(abs_grad_x, 0.5, abs_grad_y, 0.5, 0)

# %%
abs_grad_y.shape
# Out:
# (439, 611)

# %%
plt.imshow(abs_grad_x,cmap="gray")

# %%
plt.imshow(abs_grad_y,cmap="gray")

# %%
plt.imshow(grad,cmap="gray")

# %%
import numpy
